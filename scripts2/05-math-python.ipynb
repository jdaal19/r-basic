# %% [markdown]
# # Constantes en Python

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.tau
# Out:
# 6.283185307179586

# %%
2*math.pi
# Out:
# 6.283185307179586

# %%
tau = 2*math.pi
tau
# Out:
# 6.283185307179586

# %%
math.inf
# Out:
# inf

# %%
-math.inf
# Out:
# -inf

# %%
float('inf') # 8 digitos de presición.
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %%
float('nan')
# Out:
# nan

# %%
sqrt(-1.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\LENOVO~1\AppData\Local\Temp/ipykernel_3984/486990203.py in <module>
# ----> 1 sqrt(-1.0)
#
# NameError: name 'sqrt' is not defined

# %%
math.sqrt(-1.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\LENOVO~1\AppData\Local\Temp/ipykernel_3984/2508052996.py in <module>
# ----> 1 math.sqrt(-1.0)
#
# ValueError: math domain error

# %%
math.log(0.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\LENOVO~1\AppData\Local\Temp/ipykernel_3984/1162253502.py in <module>
# ----> 1 math.log(0.0)
#
# ValueError: math domain error

# %%
math.exp(1000.0)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# C:\Users\LENOVO~1\AppData\Local\Temp/ipykernel_3984/3586528505.py in <module>
# ----> 1 math.exp(1000.0)
#
# OverflowError: math range error

# %%
math.pow(math.nan, 0)
# Out:
# 1.0

# %%
math.nan+5
# Out:
# nan

# %%
math.hypot(math.nan, math.inf)
# Out:
# inf

# %% [markdown]
# # Representación numérica

# %%
2+2
# Out:
# 4

# %%
3-5
# Out:
# -2

# %%
3*5
# Out:
# 15

# %%
3/5
# Out:
# 0.6

# %%
math.ceil(3.4523)
# Out:
# 4

# %%
math.floor(3.4523)
# Out:
# 3

# %%
math.trunc(3.4523)
# Out:
# 3

# %% [markdown]
# $\int_0^1 x^2 dx$

# %%
math.copysign(3, -2)
# Out:
# -3.0

# %%
math.copysign(3, -0) # copysign copia el signo de la segunda variable sobre el valor de la primera variable.
# Out:
# 3.0

# %%
math.copysign(3, -0.0)
# Out:
# -3.0

# %%
math.fabs(5)
# Out:
# 5.0

# %%
math.fabs(-5.0)
# Out:
# 5.0

# %%
2^5
# Out:
# 7

# %%
2**5
# Out:
# 32

# %%
math.factorial(4)
# Out:
# 24

# %%
x = 5
y = 2

math.factorial(x) / (math.factorial(y) * math.factorial(x-y)) # definición combinatoria
# Out:
# 10.0

# %%
math.fmod(7,3)
# Out:
# 1.0

# %%
7%3
# Out:
# 1

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
math.remainder(7,3)
# Out:
# 1.0

# %%
math.modf(4.25)
# Out:
# (0.25, 4.0)

# %%
math.modf(-4.25)
# Out:
# (-0.25, -4.0)

# %%
math.gcd(24,36)
# Out:
# 12

# %%
math.isfinite(4.6)
# Out:
# True

# %%
math.isinf(4.5)
# Out:
# False

# %%
math.isnan(4.5)
# Out:
# False

# %%
math.sqrt(2)**2 ==2
# Out:
# False

# %%
math.isclose(math.sqrt(2)**2, 2, rel_tol=1e-09)    # para verificar si esta lo suficientemente cerca
# Out:
# True

# %%
math.sqrt(2)**2
# Out:
# 2.0000000000000004

# %% [markdown]
# # Funciones Matemáticas

# %%
math.exp(3) # mas preciso, se comprueba en los ultimos 3 decimales
# Out:
# 20.085536923187668

# %%
math.e**3
# Out:
# 20.085536923187664

# %%
math.pow(math.e,3)
# Out:
# 20.085536923187664

# %%
math.expm1(1)
# Out:
# 1.718281828459045

# %%
math.exp(1) - 1
# Out:
# 1.718281828459045

# %%
math.exp(1e-05)-1
# Out:
# 1.0000050000069649e-05

# %%
math.expm1(1e-05)
# Out:
# 1.0000050000166667e-05

# %%
math.log(12)
# Out:
# 2.4849066497880004

# %%
math.log(12,2)
# Out:
# 3.5849625007211565

# %%
math.log1p(1e-5)
# Out:
# 9.99995000033333e-06

# %%
math.log2(32)
# Out:
# 5.0

# %%
math.log10(1000000)
# Out:
# 6.0

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
math.sin(180) # en radianes
# Out:
# -0.8011526357338304

# %%
math.cos(math.pi)
# Out:
# -1.0

# %%
math.tan(math.pi/2) # tiende a infinito
# Out:
# 1.633123935319537e+16

# %%
math.asin(1)# en radianes
# Out:
# 1.5707963267948966

# %%
math.acos(1)
# Out:
# 0.0

# %%
math.atan(1)
# Out:
# 0.7853981633974483

# %%
math.degrees(0.7853981633974483)
# Out:
# 45.0

# %%
math.radians(60)
# Out:
# 1.0471975511965976

# %%
math.cos(math.radians(60))
# Out:
# 0.5000000000000001

# %%
math.hypot(3,4) # norma euclidea
# Out:
# 5.0

# %%
math.sqrt(3**2+4**2)
# Out:
# 5.0

# %%
math.atan2(4,3) # x = 3, y =4
# Out:
# 0.9272952180016122

# %%
math.degrees(math.atan2(4,3))
# Out:
# 53.13010235415598

# %%
math.sinh(0)#seno hiperbolico
# Out:
# 0.0

# %%
math.cosh(0)
# Out:
# 1.0

# %%
math.tanh(0)
# Out:
# 0.0

# %%
math.erf(0)# para funciones(funcion de distribucion normal) estadisticas realcionadas con la dist N, al calcular la distribucion normal se pasa por la funcion de error.
# Out:
# 0.0

# %%
math.erf(math.pi) # Se utiliza para obtener la funcion de distribucion acumulada de la ~ N
# Out:
# 0.9999911238536323

# %%
math.erfc(math.pi) # la c es compplementaria , se define como 1-erf de x, por tanto entrega el complementario de un numero
# Out:
# 8.876146367641612e-06

# %%
math.gamma(6) # funcion sobre los numeros enteros generaliza el factorial, la gamma sobre los numeros enteros es un numero menos que un factorial
# Out:
# 120.0

# %%
math.gamma(5.5) # el factorial generalizado
# Out:
# 52.34277778455352

# %%
math.lgamma(5) # contrario a gamma, logaritmo natural del valor absoluto de la funcion gamma en x
# Out:
# 3.178053830347945
